# %% [markdown]
# ## Arbol de decisión
# #### Angel Rubén Vázquez Rivera - A01735407

# %%
import pandas as pd
from pandas import Series,DataFrame

setInicial=pd.read_csv('./files/Vinos.csv')

#Recuperar nombres de las columnas de los atributos y la clase
atributosName=setInicial.columns[:-1] #All the atributtes
atributoClase=setInicial.columns[-1] # Only the class of the real set
#print(atributoClase)
#print(atributosName)

#Datos de los atributos
dataGral=setInicial[atributosName]
#Datos de la clase (vector de elementos reales)
claseGral=setInicial[atributoClase]

#Instancias por clase
print(claseGral.value_counts())
#print(claseGral.head())
# Out:
# Clase
# Calidad_5    681
# Calidad_7    199
# Name: count, dtype: int64

# %% [markdown]
# ## Generar un solo modelo
# Entrenamiento

# %%
""" #Para usar el calsificador o algoritmo
from sklearn.tree import DecisionTreeClassifier 
################## Clasificador ######################
clasificador = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)#  min_samples_split=50 )

################## Modelo ###########################
modelo = clasificador.fit(dataGral, claseGral)

#Creación del árbol - se muestra medio xd
from sklearn.tree import export_text
arbol=export_text(modelo, feature_names=atributosName.to_list())
print(arbol)

#Mostrar árbol bonito
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(clasificador,feature_names=atributosName.to_list(),class_names=['tested_negative','tested_positive'],filled=True)#, rounded=True)
plt.show()
 """
# Out:
# " #Para usar el calsificador o algoritmo\nfrom sklearn.tree import DecisionTreeClassifier \n################## Clasificador ######################\nclasificador = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)#  min_samples_split=50 )\n\n################## Modelo ###########################\nmodelo = clasificador.fit(dataGral, claseGral)\n\n#Creación del árbol - se muestra medio xd\nfrom sklearn.tree import export_text\narbol=export_text(modelo, feature_names=atributosName.to_list())\nprint(arbol)\n\n#Mostrar árbol bonito\nimport matplotlib.pyplot as plt\nfrom sklearn import tree\nplt.figure(figsize=(10,10))\ntree.plot_tree(clasificador,feature_names=atributosName.to_list(),class_names=['tested_negative','tested_positive'],filled=True)#, rounded=True)\nplt.show()\n "

# %% [markdown]
# Clasificación (predicción)

# %%
""" setPredic=pd.DataFrame({'preg':[1,3,7],
           'plas':[138,191,150],
           'pres':[90,68,66],
           'skin':[30,15,42],
           'insu':[150,130,342],
           'mass':[37.6,30.9,34.7],
            'pedi':[0.651,0.299,0.718],
           'age':[35,34,42]})

#Instancias por clase
print(setPredic) """
# Out:
# " setPredic=pd.DataFrame({'preg':[1,3,7],\n           'plas':[138,191,150],\n           'pres':[90,68,66],\n           'skin':[30,15,42],\n           'insu':[150,130,342],\n           'mass':[37.6,30.9,34.7],\n            'pedi':[0.651,0.299,0.718],\n           'age':[35,34,42]})\n\n#Instancias por clase\nprint(setPredic) "

# %%
#Asignar la clase
""" predict = modelo.predict(setPredic)
print(predict) """
# Out:
# ' predict = modelo.predict(setPredic)\nprint(predict) '

# %%
""" predictExp2 = modelo.predict(dataGral)
predictExp2

print(len(claseGral), len(predictExp2))

Aciertos = 0
for x in range(len(claseGral)):
    if claseGral[x] == predictExp2[x]:
        Aciertos += 1
print(Aciertos, len(claseGral) - Aciertos)
 """
#Si el arbol crece hasta su limite m[aximo, ir revisando con la poda
#como se va agregando un mayor procentaje de asertividad a los nodos
# Out:
# ' predictExp2 = modelo.predict(dataGral)\npredictExp2\n\nprint(len(claseGral), len(predictExp2))\n\nAciertos = 0\nfor x in range(len(claseGral)):\n    if claseGral[x] == predictExp2[x]:\n        Aciertos += 1\nprint(Aciertos, len(claseGral) - Aciertos)\n '

# %% [markdown]
# ##Separación de conjuntos
# Entrenamiento

# %%
from sklearn.model_selection import train_test_split

#Separar los datos
#Particiones usuales: 80/20 70/30 67/33
valoresTrain, valoresTest, clasesTrain, clasesTest = train_test_split(dataGral, claseGral, test_size=0.30)
""" print(len(valoresTrain),len(valoresTest))
print(valoresTrain.head()) """

print("Instancias de conjunto de entrenamiento")
print(clasesTrain.value_counts(), "\n")

print("Instancias de conjunto para clasificar")
print(clasesTest.value_counts())
# Out:
# Instancias de conjunto de entrenamiento
# Clase
# Calidad_5    475
# Calidad_7    141
# Name: count, dtype: int64
#
# Instancias de conjunto para clasificar
# Clase
# Calidad_5    206
# Calidad_7     58
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier 

prof = [2,3,4,5,6,7]

Train= [] 
Test = []

#Modelo
for x in prof:
################## Clasificador ######################
    clasificador = DecisionTreeClassifier(criterion = 'entropy')# max_depth = 3, min_samples_split=50 )

    ################## Modelo ###########################
    modelo = clasificador.fit(valoresTrain, clasesTrain)

    predic = modelo.predict(valoresTest)
    predicTrain = modelo.predict(valoresTrain)

    #Evaluar
    Test.append(accuracy_score(clasesTest,predic))
    Train.append(accuracy_score(clasesTrain, predicTrain))

print(Test)
print(Train)

plt.plot(prof, Train, label = "Train", color = "red", linestyle = "dotted")
plt.plot(prof, Test, label = "Test", color = "green", linestyle = "dotted")
plt.ylim(0,1)
plt.legend()

#Creación del árbol - se muestra medio xd
""" from sklearn.tree import export_text
arbol=export_text(modelo, feature_names=atributosName.to_list())
print(arbol)

#Mostrar árbol bonito
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(clasificador,feature_names=atributosName.to_list(),class_names=['tested_negative','tested_positive'],filled=True)#, rounded=True)
plt.show() """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       8 #Modelo
#       9 for x in prof:
#      10 ################## Clasificador ######################
# ---> 11     clasificador = DecisionTreeClassifier(criterion = 'entropy')# max_depth = 3, min_samples_split=50 )
#      13     ################## Modelo ###########################
#      14     modelo = clasificador.fit(valoresTrain, clasesTrain)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %% [markdown]
# Clasificación (evaluación)

# %%
from sklearn.metrics import accuracy_score
print("Exactitud: ",accuracy_score(clasesTest,predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print("Exactitud: ",accuracy_score(clasesTest,predict))
#
# NameError: name 'predict' is not defined

# %%
# %%shell
# jupyter nbconvert --to html 2_1_Arbol.ipynb
# Out:
# [NbConvertApp] Converting notebook 2_1_Arbol.ipynb to html
# [NbConvertApp] Writing 913065 bytes to 2_1_Arbol.html
